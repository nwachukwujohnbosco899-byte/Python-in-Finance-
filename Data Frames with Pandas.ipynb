# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
data_set = np.random.randint(0,101,(4,3))

# %%
data_set
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]], dtype=int32)

# %%
index_set = ['Aba', 'Umuahia', 'Adamawa', 'Yola']
column_set =['Jan', 'Feb', 'March']

# %%
pd_series = pd.DataFrame(data=data_set,index= index_set, columns= column_set)

# %%
pd_series
# Out:
#          Jan  Feb  March
# Aba       95   11     81
# Umuahia   70   63     87
# Adamawa   75    9     77
# Yola      40    4     63

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\User\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
pd_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Aba to Yola
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   March   4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
pwd
# Out:
# 'C:\\Users\\User\\Downloads\\Python-Finance-QuantConnect\\03-Core-Pandas'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8E0E-0AB3
#
#  Directory of C:\Users\User\Downloads\Python-Finance-QuantConnect\03-Core-Pandas
#
# 26/03/2026  22:46    <DIR>          .
# 25/03/2026  08:24    <DIR>          ..
# 26/03/2026  22:44    <DIR>          .ipynb_checkpoints
# 25/03/2026  08:24    <DIR>          __pycache__
# 25/03/2026  16:35           565,986 00-Series.ipynb
# 25/03/2026  18:26           209,657 01-DataFrames.ipynb
# 26/03/2026  21:31           194,875 02-Conditional-Filtering.ipynb
# 26/03/2026  22:46           197,241 03-Useful-Methods.ipynb
# 25/03/2026  08:24            62,966 04-Combining-DataFrames.ipynb
# 25/03/2026  08:24            65,234 05-Inputs-and-Outputs.ipynb
# 25/03/2026  08:24             7,809 06-Core-Pandas-Finance-Exercise.ipynb
# 25/03/2026  08:24            66,826 07-Core-Pandas-Finance-Exercise-SOLUTIONS.ipynb
# 25/03/2026  08:24            18,676 constituents.csv
# ...

# %%
file_read =pd.read_csv("tips.csv")

# %%
file_read
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
file_read.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
file_read.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
file_read.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
file_read.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
file_read.tail(1).transpose()
# Out:
#                                243
# total_bill                   18.78
# tip                            3.0
# sex                         Female
# smoker                          No
# day                           Thur
# time                        Dinner
# size                             2
# price_per_person              9.39
# Payer Name         Michelle Hardin
# CC Number         3511451626698139
# Payment ID                 Thur672

# %%
file_read[['total_bill']]
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
file_read
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
file_read= file_read.set_index('Payment ID')

# %%
file_read
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
file_read.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
file_read.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# to pick collumns

# %%
file_read [['total_bill']]
# Out:
#             total_bill
# Payment ID
# Sun2959          16.99
# Sun4608          10.34
# Sun4458          21.01
# Sun5260          23.68
# Sun2251          24.59
# ...                ...
# Sat2657          29.03
# Sat1766          27.18
# Sat3880          22.67
# Sat17            17.82
# Thur672          18.78
#
# [244 rows x 1 columns]

# %%
file_read.head(0)
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, price_per_person, Payer Name, CC Number]
# Index: []

# %%
file_read['total price']= file_read['size']*file_read['price_per_person']

# %%
file_read.head(0)
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, price_per_person, Payer Name, CC Number, total price]
# Index: []

# %%
file_read.head(5)
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             total price
# Payment ID
# Sun2959           16.98
# Sun4608           10.35
# Sun4458           21.00
# Sun5260           23.68
# ...

# %%
file_read['total_bill'] > 30
# Out:
# Payment ID
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat2657    False
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Name: total_bill, Length: 244, dtype: bool

# %%
file_read[(file_read['total_bill'] > 45) | (file_read['smoker']== 'No')]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat4615          10.07  1.25    Male     No   Sat  Dinner     2
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
str(123456789) [-10:]
# Out:
# '123456789'

# %%
def tip_good(tip):
    if tip > 1.5:
        return "good tip"
    else:
      return "bad tip"

# %%
import numpy as np
file_read['Tip_ Comment'] = np.vectorize(tip_good)(file_read['tip'])
file_read.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             total price Tip_ Comment
# Payment ID
# Sun2959           16.98      bad tip
# Sun4608           10.35     good tip
# ...
