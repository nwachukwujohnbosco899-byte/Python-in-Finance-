# %%
# import the necessary library
import numpy as np

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\User\\Downloads\\Python-Finance-QuantConnect\\03-Core-Pandas'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8E0E-0AB3
#
#  Directory of C:\Users\User\Downloads\Python-Finance-QuantConnect\03-Core-Pandas
#
# 02/04/2026  23:52    <DIR>          .
# 25/03/2026  08:24    <DIR>          ..
# 02/04/2026  23:13    <DIR>          .ipynb_checkpoints
# 25/03/2026  08:24    <DIR>          __pycache__
# 01/04/2026  12:27           565,986 00-Series.ipynb
# 25/03/2026  18:26           209,657 01-DataFrames.ipynb
# 26/03/2026  21:31           194,875 02-Conditional-Filtering.ipynb
# 01/04/2026  15:03           197,241 03-Useful-Methods.ipynb
# 01/04/2026  11:49            63,042 04-Combining-DataFrames.ipynb
# 01/04/2026  11:49            65,310 05-Inputs-and-Outputs.ipynb
# 27/03/2026  10:06             8,778 06-Core-Pandas-Finance-Exercise.ipynb
# 02/04/2026  20:36             8,365 06-Core-Pandas-Finance-Exercise-Copy1.ipynb
# 02/04/2026  23:51            72,359 07-Core-Pandas-Finance-Exercise-SOLUTIONS.ipynb
# ...

# %%
df=pd.read_csv('constituents.csv')

# %%
df
# Out:
#     Symbol                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    XYL              Xylem Inc.             Industrials
# 501    YUM         Yum! Brands Inc  Consumer Discretionary
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
df1= pd.read_csv('constituents-financials.csv')

# %%
df1
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# ...

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', 'Sector'], dtype='object')

# %%
df1.columns
# Out:
# Index(['Symbol', 'Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share',
#        '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA', 'Price/Sales',
#        'Price/Book', 'SEC Filings'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of     Symbol                    Name                  Sector
# 0      MMM              3M Company             Industrials
# 1      AOS         A.O. Smith Corp             Industrials
# 2      ABT     Abbott Laboratories             Health Care
# 3     ABBV             AbbVie Inc.             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    XYL              Xylem Inc.             Industrials
# 501    YUM         Yum! Brands Inc  Consumer Discretionary
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
# [505 rows x 3 columns]>

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# ...

# %%
#get the first five info of the first and second data
df.head()
# Out:
#   Symbol                 Name                  Sector
# 0    MMM           3M Company             Industrials
# 1    AOS      A.O. Smith Corp             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV          AbbVie Inc.             Health Care
# 4    ACN        Accenture plc  Information Technology

# %%
df1.head()
# Out:
#   Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0    MMM  222.89           24.31        2.332862            7.92       259.77
# 1    AOS   60.24           27.76        1.147959            1.70        68.39
# 2    ABT   56.27           22.51        1.908982            0.26        64.60
# 3   ABBV  108.48           19.41        2.499560            3.29       125.86
# 4    ACN  150.51           25.47        1.714470            5.44       162.60
#
#    52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# 0       175.490  138721055226  9.048000e+09     4.390271       11.34
# 1        48.925   10783419933  6.010000e+08     3.575483        6.35
# 2        42.280  102121042306  5.744000e+09     3.740480        3.19
# 3        60.050  181386347059  1.031000e+10     6.291571       26.14
# 4       114.820   98765855553  5.643228e+09     2.604117       10.62
#
#                                          SEC Filings
# ...

# %%
df1= df1.drop( 'SEC Filings',axis=1)

# %%
df1
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 500    XYL   70.24           30.94        1.170079            1.83
# 501    YUM   76.30           27.25        1.797080            4.07
# 502    ZBH  115.53           14.32        0.794834            9.01
# 503   ZION   50.71           17.73        1.480933            2.60
# 504    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# ...

# %%
df1=df1.set_index('Symbol')

# %%
df1
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
df1.nlargest(10,'Market Cap')
# this returns the information about the 10 companies with the largest market cap
# Out:
#           Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# AAPL     155.15           16.86        1.579541            9.20     180.1000
# GOOGL   1007.71           31.48        0.000000           22.27    1198.0000
# GOOG    1001.52           40.29        0.000000           22.27    1186.8900
# MSFT      85.01           25.76        1.874791            2.97      96.0700
# AMZN    1350.50          296.16        0.000000            6.16    1498.0000
# FB       171.58           27.90        0.000000            5.39     195.3200
# JPM      107.88           15.43        1.984584            6.30     117.3529
# JNJ      126.36           17.31        2.556688            0.39     148.3200
# XOM       76.07           21.37        4.003120            1.88      89.3000
# BAC       29.74           16.34        1.536000            1.55      32.6700
#
#         52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book
# Symbol
# ...

# %%
df1=df1.drop('GOOG',axis=0)

# %%
df1
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
len(df1[df1['Dividend Yield']>4])
#checks the number of companies that have dividend Yield greater than 4
# Out:
# 37

# %%
df1[df1['Dividend Yield']>4]
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# AES      10.06            9.96        4.961832           -1.72      12.0500
# T        35.57           12.14        5.415651            4.76      42.7000
# CNP      25.85           19.73        4.210926            1.00      30.4500
# CTL      16.20            8.35       12.661196            1.16      27.6100
# D        73.31           20.42        4.528200            4.91      85.3000
# DUK      74.32           16.70        4.784946            3.12      91.8000
# EIX      58.07           13.23        4.054280            3.96      83.3800
# ETR      72.02           10.65        4.892126           -3.26      87.9500
# XOM      76.07           21.37        4.003120            1.88      89.3000
# FE       30.64           11.18        4.673807          -14.49      35.2200
# F        10.43            5.89        6.784387            1.90      13.4800
# ...

# %%
df1[df1["Market Cap"] > 1e+11]["Earnings/Share"].mean()
# mean of earning per share ratio of companies with EBITDA higher than 1e + 4
# Out:
# np.float64(4.746470588235294)

# %%
(df1['Earnings/Share']>=0).sum()
#number of companies with positive earnings per share ratio
# Out:
# np.int64(453)

# %%
df1.columns
# Out:
# Index(['Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share',
#        '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA', 'Price/Sales',
#        'Price/Book'],
#       dtype='object')

# %%
df1['Dividend Yield'].max()
# Out:
# 12.661196

# %%
df1.nlargest(1,'Dividend Yield').iloc[0]
# shows the company with the highest dividend yield and it's 52 week high
# Out:
# Price             1.620000e+01
# Price/Earnings    8.350000e+00
# Dividend Yield    1.266120e+01
# Earnings/Share    1.160000e+00
# 52 Week Low       2.761000e+01
# 52 Week High      1.316100e+01
# Market Cap        1.823720e+10
# EBITDA            5.577000e+09
# Price/Sales       1.479598e+00
# Price/Book        1.390000e+00
# Name: CTL, dtype: float64

# %%
index = abs(df1["52 Week High"] - df1["52 Week Low"]).idxmax()
df1.loc[index]
# Out:
# Price             1.350500e+03
# Price/Earnings    2.961600e+02
# Dividend Yield    0.000000e+00
# Earnings/Share    6.160000e+00
# 52 Week Low       1.498000e+03
# 52 Week High      8.125000e+02
# Market Cap        6.858734e+11
# EBITDA            1.613200e+10
# Price/Sales       3.927053e+00
# Price/Book        2.428000e+01
# Name: AMZN, dtype: float64

# %%
df1['Spread']= abs(df1['52 Week High']-df1['52 Week Low'])

# %%
df1
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
df1['Spread'].max()
# Out:
# 685.5

# %%
df1.nlargest(1,'Spread')
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# AMZN    1350.5          296.16             0.0            6.16       1498.0
#
#         52 Week High    Market Cap        EBITDA  Price/Sales  Price/Book  \
# Symbol
# AMZN           812.5  685873374731  1.613200e+10     3.927053       24.28
#
#         Spread
# Symbol
# AMZN     685.5

# %%
df1[(df1['Price']>=50) & (df1['Price']<=100)]
#or you can use this code df1[df1['Price].between(50,100)]
# this is used  to check the prices between two prices
# Out:
#         Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# AOS     60.24           27.76        1.147959            1.70       68.390
# ABT     56.27           22.51        1.908982            0.26       64.600
# ATVI    65.83           31.80        0.431903            1.28       74.945
# AFL     83.25           12.24        2.429907           11.01       91.730
# A       65.05           27.45        0.875698            2.10       75.000
# ...       ...             ...             ...             ...          ...
# XLNX    62.82           27.19        2.090488            2.32       77.260
# XYL     70.24           30.94        1.170079            1.83       76.810
# YUM     76.30           27.25        1.797080            4.07       86.930
# ZION    50.71           17.73        1.480933            2.60       55.610
# ZTS     71.51           32.80        0.682372            1.65       80.130
#
# ...

# %%
df1['Market Cap in Billion']=df1['Market Cap']/1000000000

# %%
df1
# Out:
#          Price  Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# Symbol
# MMM     222.89           24.31        2.332862            7.92       259.77
# AOS      60.24           27.76        1.147959            1.70        68.39
# ABT      56.27           22.51        1.908982            0.26        64.60
# ABBV    108.48           19.41        2.499560            3.29       125.86
# ACN     150.51           25.47        1.714470            5.44       162.60
# ...        ...             ...             ...             ...          ...
# XYL      70.24           30.94        1.170079            1.83        76.81
# YUM      76.30           27.25        1.797080            4.07        86.93
# ZBH     115.53           14.32        0.794834            9.01       133.49
# ZION     50.71           17.73        1.480933            2.60        55.61
# ZTS      71.51           32.80        0.682372            1.65        80.13
#
# ...

# %%
df1[['Market Cap','Dividend Yield']].corr()
# Out:
#                 Market Cap  Dividend Yield
# Market Cap        1.000000       -0.003506
# Dividend Yield   -0.003506        1.000000

# %%
df1.columns
# Out:
# Index(['Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share',
#        '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA', 'Price/Sales',
#        'Price/Book', 'Spread', 'Market Cap in Billion'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', 'Sector'], dtype='object')

# %%
df3=pd.merge(df1,df,on='Symbol')

# %%
df3
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 499    XYL   70.24           30.94        1.170079            1.83
# 500    YUM   76.30           27.25        1.797080            4.07
# 501    ZBH  115.53           14.32        0.794834            9.01
# 502   ZION   50.71           17.73        1.480933            2.60
# 503    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# ...

# %%
df3.columns
# Out:
# Index(['Symbol', 'Price', 'Price/Earnings', 'Dividend Yield', 'Earnings/Share',
#        '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA', 'Price/Sales',
#        'Price/Book', 'Spread', 'Market Cap in Billion', 'Name', 'Sector'],
#       dtype='object')

# %%
df3['Sector']
# Out:
# 0                 Industrials
# 1                 Industrials
# 2                 Health Care
# 3                 Health Care
# 4      Information Technology
#                 ...
# 499               Industrials
# 500    Consumer Discretionary
# 501               Health Care
# 502                Financials
# 503               Health Care
# Name: Sector, Length: 504, dtype: object

# %%
df3['Sector'].replace(['Information Technology'],['IT'],inplace=True)

# %%
df3
# Out:
#     Symbol   Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  222.89           24.31        2.332862            7.92
# 1      AOS   60.24           27.76        1.147959            1.70
# 2      ABT   56.27           22.51        1.908982            0.26
# 3     ABBV  108.48           19.41        2.499560            3.29
# 4      ACN  150.51           25.47        1.714470            5.44
# ..     ...     ...             ...             ...             ...
# 499    XYL   70.24           30.94        1.170079            1.83
# 500    YUM   76.30           27.25        1.797080            4.07
# 501    ZBH  115.53           14.32        0.794834            9.01
# 502   ZION   50.71           17.73        1.480933            2.60
# 503    ZTS   71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# ...

# %%
num=100
'$'+ str(num)
# Out:
# '$100'

# %%
def price(num):
    return '$'+str(num)

# %%
df3['Price']=np.vectorize(price)(df3['Price'])
#add $ to the numbers in the price

# %%
df3
# Out:
#     Symbol    Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# 0      MMM  $222.89           24.31        2.332862            7.92
# 1      AOS   $60.24           27.76        1.147959            1.70
# 2      ABT   $56.27           22.51        1.908982            0.26
# 3     ABBV  $108.48           19.41        2.499560            3.29
# 4      ACN  $150.51           25.47        1.714470            5.44
# ..     ...      ...             ...             ...             ...
# 499    XYL   $70.24           30.94        1.170079            1.83
# 500    YUM    $76.3           27.25        1.797080            4.07
# 501    ZBH  $115.53           14.32        0.794834            9.01
# 502   ZION   $50.71           17.73        1.480933            2.60
# 503    ZTS   $71.51           32.80        0.682372            1.65
#
#      52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# 0         259.77       175.490  138721055226  9.048000e+09     4.390271
# ...
